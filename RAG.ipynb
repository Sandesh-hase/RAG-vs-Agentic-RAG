# %% [markdown]
# # Agentic RAG
# #

# %% [markdown]
# ### Sparse vs Dense Retrieval

# %% [markdown]
# <img src="sparse_vs_dense_retrieval.png" alt="Sparse vs Dense Retrieval" width="800">

# %% [markdown]
# ## Dense Retrieval using DPR + FAISS
# This notebook demonstrates how to encode passages and queries using DPR and perform semantic search using FAISS.

# %% [markdown]
# <img src="dpr_matching.gif" alt="DPR" width="800">

# %% [markdown]
# <img src="DPR.png" alt="DPR" width="800">

# %%
# Install required libraries (uncomment if needed)
# !pip install sentence-transformers faiss-cpu
# Out:
# Collecting sentence-transformers
#   Using cached sentence_transformers-5.1.0-py3-none-any.whl.metadata (16 kB)
# Collecting faiss-cpu
#   Using cached faiss_cpu-1.12.0-cp313-cp313-win_amd64.whl.metadata (5.2 kB)
# Collecting transformers<5.0.0,>=4.41.0 (from sentence-transformers)
#   Using cached transformers-4.56.1-py3-none-any.whl.metadata (42 kB)
# Requirement already satisfied: tqdm in c:\users\sandesh\appdata\local\programs\python\python313\lib\site-packages (from sentence-transformers) (4.67.1)
# Collecting torch>=1.11.0 (from sentence-transformers)
#   Using cached torch-2.8.0-cp313-cp313-win_amd64.whl.metadata (30 kB)
# Collecting scikit-learn (from sentence-transformers)
#   Downloading scikit_learn-1.7.1-cp313-cp313-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: scipy in c:\users\sandesh\appdata\local\programs\python\python313\lib\site-packages (from sentence-transformers) (1.16.0)
# Collecting huggingface-hub>=0.20.0 (from sentence-transformers)
#   Using cached huggingface_hub-0.34.4-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: Pillow in c:\users\sandesh\appdata\local\programs\python\python313\lib\site-packages (from sentence-transformers) (11.3.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\sandesh\appdata\local\programs\python\python313\lib\site-packages (from sentence-transformers) (4.14.1)
# Collecting filelock (from transformers<5.0.0,>=4.41.0->sentence-transformers)
#   Downloading filelock-3.19.1-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: numpy>=1.17 in c:\users\sandesh\appdata\local\programs\python\python313\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2.3.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\sandesh\appdata\local\programs\python\python313\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\sandesh\appdata\local\programs\python\python313\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\sandesh\appdata\local\programs\python\python313\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.11.6)
# Requirement already satisfied: requests in c:\users\sandesh\appdata\local\programs\python\python313\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2.32.4)
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers<5.0.0,>=4.41.0->sentence-transformers)
#   Using cached tokenizers-0.22.0-cp39-abi3-win_amd64.whl.metadata (6.9 kB)
# Collecting safetensors>=0.4.3 (from transformers<5.0.0,>=4.41.0->sentence-transformers)
#   Using cached safetensors-0.6.2-cp38-abi3-win_amd64.whl.metadata (4.1 kB)
# Collecting fsspec>=2023.5.0 (from huggingface-hub>=0.20.0->sentence-transformers)
#   Downloading fsspec-2025.9.0-py3-none-any.whl.metadata (10 kB)
# Collecting sympy>=1.13.3 (from torch>=1.11.0->sentence-transformers)
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch>=1.11.0->sentence-transformers)
#   Using cached networkx-3.5-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: jinja2 in c:\users\sandesh\appdata\local\programs\python\python313\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\sandesh\appdata\local\programs\python\python313\lib\site-packages (from torch>=1.11.0->sentence-transformers) (80.9.0)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: colorama in c:\users\sandesh\appdata\local\programs\python\python313\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sandesh\appdata\local\programs\python\python313\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\sandesh\appdata\local\programs\python\python313\lib\site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sandesh\appdata\local\programs\python\python313\lib\site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sandesh\appdata\local\programs\python\python313\lib\site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sandesh\appdata\local\programs\python\python313\lib\site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (2025.7.14)
# Collecting joblib>=1.2.0 (from scikit-learn->sentence-transformers)
#   Downloading joblib-1.5.2-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn->sentence-transformers)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Using cached sentence_transformers-5.1.0-py3-none-any.whl (483 kB)
# Using cached transformers-4.56.1-py3-none-any.whl (11.6 MB)
# Using cached huggingface_hub-0.34.4-py3-none-any.whl (561 kB)
# Using cached tokenizers-0.22.0-cp39-abi3-win_amd64.whl (2.7 MB)
# Using cached faiss_cpu-1.12.0-cp313-cp313-win_amd64.whl (18.2 MB)
# Downloading fsspec-2025.9.0-py3-none-any.whl (199 kB)
# Using cached safetensors-0.6.2-cp38-abi3-win_amd64.whl (320 kB)
# Using cached torch-2.8.0-cp313-cp313-win_amd64.whl (241.3 MB)
# Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Downloading filelock-3.19.1-py3-none-any.whl (15 kB)
# Using cached networkx-3.5-py3-none-any.whl (2.0 MB)
# Downloading scikit_learn-1.7.1-cp313-cp313-win_amd64.whl (8.7 MB)
#    ---------------------------------------- 0.0/8.7 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.7 MB 4.5 MB/s eta 0:00:02
#    ------- -------------------------------- 1.6/8.7 MB 4.5 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.4/8.7 MB 4.4 MB/s eta 0:00:02
#    --------------- ------------------------ 3.4/8.7 MB 4.4 MB/s eta 0:00:02
#    ------------------ --------------------- 3.9/8.7 MB 4.4 MB/s eta 0:00:02
#    --------------------- ------------------ 4.7/8.7 MB 4.3 MB/s eta 0:00:01
#    -------------------------- ------------- 5.8/8.7 MB 4.2 MB/s eta 0:00:01
#    ------------------------------ --------- 6.6/8.7 MB 4.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 7.6/8.7 MB 4.3 MB/s eta 0:00:01
#    -------------------------------------- - 8.4/8.7 MB 4.4 MB/s eta 0:00:01
#    ---------------------------------------- 8.7/8.7 MB 4.3 MB/s eta 0:00:00
# Downloading joblib-1.5.2-py3-none-any.whl (308 kB)
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: mpmath, threadpoolctl, sympy, safetensors, networkx, joblib, fsspec, filelock, faiss-cpu, torch, scikit-learn, huggingface-hub, tokenizers, transformers, sentence-transformers
#
#    ----------------------------------------  0/15 [mpmath]
#    ----------------------------------------  0/15 [mpmath]
#    ----------------------------------------  0/15 [mpmath]
#    ----------------------------------------  0/15 [mpmath]
#    ----------------------------------------  0/15 [mpmath]
#    ----------------------------------------  0/15 [mpmath]
#    ----------------------------------------  0/15 [mpmath]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    ----- ----------------------------------  2/15 [sympy]
#    -------- -------------------------------  3/15 [safetensors]
#    ---------- -----------------------------  4/15 [networkx]
#    ---------- -----------------------------  4/15 [networkx]
#    ---------- -----------------------------  4/15 [networkx]
#    ---------- -----------------------------  4/15 [networkx]
#    ---------- -----------------------------  4/15 [networkx]
#    ---------- -----------------------------  4/15 [networkx]
#    ---------- -----------------------------  4/15 [networkx]
#    ---------- -----------------------------  4/15 [networkx]
#    ---------- -----------------------------  4/15 [networkx]
#    ---------- -----------------------------  4/15 [networkx]
#    ---------- -----------------------------  4/15 [networkx]
#    ---------- -----------------------------  4/15 [networkx]
#    ---------- -----------------------------  4/15 [networkx]
#    ---------- -----------------------------  4/15 [networkx]
#    ---------- -----------------------------  4/15 [networkx]
#    ---------- -----------------------------  4/15 [networkx]
#    ---------- -----------------------------  4/15 [networkx]
#    ---------- -----------------------------  4/15 [networkx]
#    ---------- -----------------------------  4/15 [networkx]
#    ---------- -----------------------------  4/15 [networkx]
#    ---------- -----------------------------  4/15 [networkx]
#    ---------- -----------------------------  4/15 [networkx]
#    ---------- -----------------------------  4/15 [networkx]
#    ---------- -----------------------------  4/15 [networkx]
#    ---------- -----------------------------  4/15 [networkx]
#    ---------- -----------------------------  4/15 [networkx]
#    ---------- -----------------------------  4/15 [networkx]
#    ---------- -----------------------------  4/15 [networkx]
#    ---------- -----------------------------  4/15 [networkx]
#    ---------- -----------------------------  4/15 [networkx]
#    ---------- -----------------------------  4/15 [networkx]
#    ---------- -----------------------------  4/15 [networkx]
#    ---------- -----------------------------  4/15 [networkx]
#    ---------- -----------------------------  4/15 [networkx]
#    ---------- -----------------------------  4/15 [networkx]
#    ---------- -----------------------------  4/15 [networkx]
#    ---------- -----------------------------  4/15 [networkx]
#    ---------- -----------------------------  4/15 [networkx]
#    ---------- -----------------------------  4/15 [networkx]
#    ---------- -----------------------------  4/15 [networkx]
#    ---------- -----------------------------  4/15 [networkx]
#    ---------- -----------------------------  4/15 [networkx]
#    ---------- -----------------------------  4/15 [networkx]
#    ---------- -----------------------------  4/15 [networkx]
#    ------------- --------------------------  5/15 [joblib]
#    ------------- --------------------------  5/15 [joblib]
#    ------------- --------------------------  5/15 [joblib]
#    ------------- --------------------------  5/15 [joblib]
#    ------------- --------------------------  5/15 [joblib]
#    ---------------- -----------------------  6/15 [fsspec]
#    ---------------- -----------------------  6/15 [fsspec]
#    ---------------- -----------------------  6/15 [fsspec]
#    ---------------- -----------------------  6/15 [fsspec]
#    ------------------ ---------------------  7/15 [filelock]
#    --------------------- ------------------  8/15 [faiss-cpu]
#    --------------------- ------------------  8/15 [faiss-cpu]
#    --------------------- ------------------  8/15 [faiss-cpu]
#    --------------------- ------------------  8/15 [faiss-cpu]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    ------------------------ ---------------  9/15 [torch]
#    -------------------------- ------------- 10/15 [scikit-learn]
#    -------------------------- ------------- 10/15 [scikit-learn]
#    -------------------------- ------------- 10/15 [scikit-learn]
#    -------------------------- ------------- 10/15 [scikit-learn]
#    -------------------------- ------------- 10/15 [scikit-learn]
#    -------------------------- ------------- 10/15 [scikit-learn]
#    -------------------------- ------------- 10/15 [scikit-learn]
#    -------------------------- ------------- 10/15 [scikit-learn]
#    -------------------------- ------------- 10/15 [scikit-learn]
#    -------------------------- ------------- 10/15 [scikit-learn]
#    -------------------------- ------------- 10/15 [scikit-learn]
#    -------------------------- ------------- 10/15 [scikit-learn]
#    -------------------------- ------------- 10/15 [scikit-learn]
#    -------------------------- ------------- 10/15 [scikit-learn]
#    -------------------------- ------------- 10/15 [scikit-learn]
#    -------------------------- ------------- 10/15 [scikit-learn]
#    -------------------------- ------------- 10/15 [scikit-learn]
#    -------------------------- ------------- 10/15 [scikit-learn]
#    -------------------------- ------------- 10/15 [scikit-learn]
#    -------------------------- ------------- 10/15 [scikit-learn]
#    -------------------------- ------------- 10/15 [scikit-learn]
#    -------------------------- ------------- 10/15 [scikit-learn]
#    -------------------------- ------------- 10/15 [scikit-learn]
#    -------------------------- ------------- 10/15 [scikit-learn]
#    -------------------------- ------------- 10/15 [scikit-learn]
#    -------------------------- ------------- 10/15 [scikit-learn]
#    -------------------------- ------------- 10/15 [scikit-learn]
#    -------------------------- ------------- 10/15 [scikit-learn]
#    -------------------------- ------------- 10/15 [scikit-learn]
#    -------------------------- ------------- 10/15 [scikit-learn]
#    -------------------------- ------------- 10/15 [scikit-learn]
#    -------------------------- ------------- 10/15 [scikit-learn]
#    -------------------------- ------------- 10/15 [scikit-learn]
#    -------------------------- ------------- 10/15 [scikit-learn]
#    -------------------------- ------------- 10/15 [scikit-learn]
#    -------------------------- ------------- 10/15 [scikit-learn]
#    -------------------------- ------------- 10/15 [scikit-learn]
#    -------------------------- ------------- 10/15 [scikit-learn]
#    -------------------------- ------------- 10/15 [scikit-learn]
#    -------------------------- ------------- 10/15 [scikit-learn]
#    -------------------------- ------------- 10/15 [scikit-learn]
#    -------------------------- ------------- 10/15 [scikit-learn]
#    -------------------------- ------------- 10/15 [scikit-learn]
#    -------------------------- ------------- 10/15 [scikit-learn]
#    -------------------------- ------------- 10/15 [scikit-learn]
#    ----------------------------- ---------- 11/15 [huggingface-hub]
#    ----------------------------- ---------- 11/15 [huggingface-hub]
#    ----------------------------- ---------- 11/15 [huggingface-hub]
#    ----------------------------- ---------- 11/15 [huggingface-hub]
#    ----------------------------- ---------- 11/15 [huggingface-hub]
#    ----------------------------- ---------- 11/15 [huggingface-hub]
#    ----------------------------- ---------- 11/15 [huggingface-hub]
#    ----------------------------- ---------- 11/15 [huggingface-hub]
#    ----------------------------- ---------- 11/15 [huggingface-hub]
#    ----------------------------- ---------- 11/15 [huggingface-hub]
#    ----------------------------- ---------- 11/15 [huggingface-hub]
#    ----------------------------- ---------- 11/15 [huggingface-hub]
#    ----------------------------- ---------- 11/15 [huggingface-hub]
#    -------------------------------- ------- 12/15 [tokenizers]
#    -------------------------------- ------- 12/15 [tokenizers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ---------------------------------- ----- 13/15 [transformers]
#    ------------------------------------- -- 14/15 [sentence-transformers]
#    ------------------------------------- -- 14/15 [sentence-transformers]
#    ------------------------------------- -- 14/15 [sentence-transformers]
#    ------------------------------------- -- 14/15 [sentence-transformers]
#    ------------------------------------- -- 14/15 [sentence-transformers]
#    ------------------------------------- -- 14/15 [sentence-transformers]
#    ------------------------------------- -- 14/15 [sentence-transformers]
#    ------------------------------------- -- 14/15 [sentence-transformers]
#    ------------------------------------- -- 14/15 [sentence-transformers]
#    ------------------------------------- -- 14/15 [sentence-transformers]
#    ------------------------------------- -- 14/15 [sentence-transformers]
#    ------------------------------------- -- 14/15 [sentence-transformers]
#    ------------------------------------- -- 14/15 [sentence-transformers]
#    ---------------------------------------- 15/15 [sentence-transformers]
#
# Successfully installed faiss-cpu-1.12.0 filelock-3.19.1 fsspec-2025.9.0 huggingface-hub-0.34.4 joblib-1.5.2 mpmath-1.3.0 networkx-3.5 safetensors-0.6.2 scikit-learn-1.7.1 sentence-transformers-5.1.0 sympy-1.14.0 threadpoolctl-3.6.0 tokenizers-0.22.0 torch-2.8.0 transformers-4.56.1
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sentence_transformers import SentenceTransformer
import faiss
import numpy as np

# %% [markdown]
# ## Load DPR Question Encoder
# We load a pretrained Dense Passage Retrieval (DPR) model from Hugging Face.

# %%
model = SentenceTransformer("facebook-dpr-question_encoder-single-nq-base")

# %% [markdown]
# ## Define Knowledge Base (Passages)
# These are example sentences for the search. In real-world scenarios, this can be thousands of documents.

# %%
passages = [
    "The capital of France is Paris.",
    "The heart pumps blood throughout the body.",
    "Transformers are neural network architectures designed for sequence modeling."
]

# %% [markdown]
# ## Encode Passages
# Convert textual passages into vector embeddings for similarity search.

# %%
passage_embeddings = model.encode(passages, convert_to_numpy=True, normalize_embeddings=True)

# %%
len(passage_embeddings[0])
# Out:
# 768

# %%
passage_embeddings.shape
# Out:
# (3, 768)

# %% [markdown]
# ## Build FAISS Index
# We create an index for fast similarity search using inner product (cosine similarity after normalization).

# %%
dim = passage_embeddings.shape[1]
index = faiss.IndexFlatIP(dim)
index.add(passage_embeddings)

# %%
dim
# Out:
# 768

# %% [markdown]
# ## Encode Query
# Convert the user query into the same embedding space as the passages.

#          3.71340837e-04, -1.02860546e-02,  1.43553820e-02,
#          1.26525760e-02, -8.38494301e-03, -9.87301674e-03,
#         -4.11126167e-02,  2.42554341e-02,  2.70377882e-02,
#         -2.33368482e-02,  2.61685066e-03,  1.55112392e-03,
#          1.43730845e-02, -1.67193450e-02, -4.35615750e-03,
#          8.94121546e-03, -9.14418418e-03, -2.12738495e-02,
#         -2.18418222e-02,  3.58026451e-03, -1.17209349e-02,
#         -1.41678378e-02,  8.88319965e-03, -3.33265513e-02,
#         -1.67108700e-02, -3.76779623e-02, -3.56066935e-02,
#          6.60344784e-04,  1.18292132e-02, -2.51346640e-02,
#          3.61152762e-03, -1.56105449e-02, -2.94028930e-02,
#         -3.56929973e-02, -9.43514984e-03, -1.63667761e-02,
#         -2.15289760e-02,  8.21197219e-03, -6.66479673e-03,
#          1.84044149e-02, -3.58622558e-02,  1.43997204e-02,
#         -1.75681431e-02, -2.27486584e-02, -2.05705245e-03,
#          6.37088493e-02, -2.18389258e-02, -4.00619991e-02,
#         -8.85666255e-03,  4.93701510e-02,  2.77230120e-03,
#          2.80617140e-02,  7.30949687e-03, -3.04736849e-02,
#         -2.12554671e-02, -6.50025392e-03, -3.43781188e-02,
#         -1.01860240e-02,  4.46091294e-02, -2.48229001e-02,
#         -8.90598167e-03, -1.18754487e-02,  4.22823839e-02,
#          2.95257680e-02, -1.58455111e-02, -6.99112471e-03,
#         -1.43988803e-02,  1.42730558e-02,  8.93118046e-03,
#         -1.11298673e-02, -1.82549320e-02,  5.85426530e-03,
#         -7.65896984e-04, -6.51515380e-04, -1.51038943e-02,
#         -1.28732091e-02,  7.33595458e-04, -1.01276245e-02,
#          8.63078143e-03, -4.95283939e-02, -2.99012363e-02,
#          2.79456191e-02,  3.42725143e-02, -4.80286852e-02,
#          1.52431307e-02, -2.06760317e-02,  2.19201781e-02,
#          1.50515456e-02, -1.95503025e-03, -1.39723327e-02,
#         -3.93065065e-03,  2.83040688e-03, -6.73292438e-03,
#         -1.28438184e-02, -2.36949436e-02,  2.41160914e-02,
#          1.64900068e-02,  2.41849273e-02,  9.66107566e-03,
#          1.86698753e-02, -1.70885623e-02,  2.98878755e-02,
#         -3.26328352e-02,  2.50487681e-02,  7.31266616e-03]], dtype=float32)

# %% [markdown]
# ## Search Top-k Similar Passages
# Retrieve the most relevant passages for the query.

# %%
k = 2
D, I = index.search(query_embedding, k)

# %%
D, I
# Out:
# (array([[0.9066088, 0.6765148]], dtype=float32), array([[0, 1]]))

# %%
D[0][0]
# Out:
# np.float32(0.94370985)

# %% [markdown]
# ## Display Results
# Print the top-k passages along with their similarity scores.

# %%
print("Query:", query)
for rank, idx in enumerate(I[0]):
    print(f"Rank {rank+1}: {passages[idx]} (score={D[0][rank]:.4f})")
# Out:
# Query: capital of France?
# Rank 1: The capital of France is Paris. (score=0.9066)
# Rank 2: The heart pumps blood throughout the body. (score=0.6765)
